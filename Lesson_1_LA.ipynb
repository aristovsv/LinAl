# %%
import numpy as np
from numpy.linalg import norm

# %% [markdown]
# __1.__ Исследуйте на линейную зависимость:
#
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$

# %% [markdown]
# В данном примере присутствует линейная зависимость, так как мы можем выразить $$f_{4}(x) = f_{3}(x) - f_{1}(x) - f_{2}(x)$$

# %% [markdown]
# __2.__ Исследуйте на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$$

# %% [markdown]
# В данном примере также присутствует линейная зависимость, так как мы можем выразить $$f_{4}(x) = f_{3}(x) + 2f_{2}(x) + f_{1}(x) * 0,5$$
#
# $$f_{4}(x) = x^2 + 2x + 2 * 0,5$$

# %% [markdown]
# __3.__ Найдите координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.

# %% [markdown]
# $$\alpha_{1}(0, 0, 10) + \alpha_{2}(2, 0, 0) + \alpha_{3}(0, 1, 0) = (0, 0, 0)$$
# Решая эту систему, получим α1 = α2 = α3 = 0, т. е. векторы b1, b2, b3 линейно независимы, поэтому они образуют базис пространства R^3.
#
# Найдём координаты x1, x2, x3 вектора x в этом базисе:
# $$x{1}(0, 0, 10) + x{2}(2, 0, 0) + x{3}(0, 1, 0) = (2, 3, 5)$$
#
# $$2x{2} = 2; x{3} = 3; 10x{1} = 5$$
#
# Координаты будут (0.5, 1, 3)

# %% [markdown]
# __4.__ Найдите координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# а) в базисе $1$, $x$, $x^{2}$;
#
# б) в базисе $x^{2}$, $x-1$, $1$.

# %% [markdown]
# a) $$\alpha_{1}(1, 0, 0) + \alpha_{2}(0, x, 0) + \alpha_{3}(0, 0, x^2) = (0, 0, 0)$$
# Решая эту систему, получим α1 = α2 = α3 = 0, т. е. векторы b1, b2, b3 линейно независимы, поэтому они образуют базис пространства R^3.
#
# Найдём координаты c1, c2, c3 вектора x в этом базисе:
# $$c{1}(1, 0, 0) + c{2}(0, x, 0) + c{3}(0, 0, x^2) = (3x^2, -2x, 2)$$
#
# $$c{1} = 2;   xc{2} = -2x;   x^2c{3} = 3x^2$$
#
# Координаты будут (2, -2, 3)

# %% [markdown]
# b) По аналогии с решением выше координаты в базисе 𝑥2, 𝑥−1, 1 равны (3, -2, 2)

# %% [markdown]
# __5.__ Установите, считается ли линейным подпространством:
#
# а) совокупность всех векторов трёхмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# б) все векторы, считающиеся линейными комбинациями данных векторов $\{u_{1}, u_{2} \ldots, u_{n}\}$.

# %% [markdown]
# a) Пусть даны векторы (0, a, b), (0, c, d), (0, 0, b).
#
# $$(0, a, b) + (0, c, d) = (0, a + b, c + d)$$
# $$\alpha(0, a, b) = (0, \alpha a, \alpha b)$$
#
# Полученные векторы принадлежат указанному множеству всех векторов вида , то есть это множество считается подпространством линейного пространства.

# %% [markdown]
# b) Т.к. сумма линейных комбинаций векторов  и произведение линейной комбинации этих векторов на число также являются линейными
# комбинациями данных векторов, то множество всех линейных комбинаций векторов является замкнутым относительно сложения векторов
# и умножения векторов на число, т.е. подпространство считается линейным

# %% [markdown]
# ### Part II

# %% [markdown]
# __1.__ Найдите скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$

# %%
x = np.array([0, -3, 6])
y = np.array([-4, 7, 9])
print(f'Скалярное произведение x и y:\n{np.dot(x, y)}')
# Out:
# Скалярное произведение x и y:
# 33

# %%
x = np.array([7, -4, 0, 1])
y = np.array([-3, 1, 11, 2])
print(f'Скалярное произведение x и y:\n{np.dot(x, y)}')
# Out:
# Скалярное произведение x и y:
# -23

# %% [markdown]
# __2.__ Найдите нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.

# %%
a = np.array([4, 2, 4])
b = np.array([12, 3, 4])

print(f'l1 Манхэттенская норма вектора a:\n{norm(a, ord=1)}')
print(f'l2 Евклидова норма вектора а:\n{norm(a, ord=2)}')

print(f'l1 Манхэттенская норма вектора b:\n{norm(b, ord=1)}')
print(f'l2 Евклидова норма вектора b:\n{norm(b, ord=2)}')
# Out:
# l1 Манхэттенская норма вектора a:
# 10.0
# l2 Евклидова норма вектора а:
# 6.0
# l1 Манхэттенская норма вектора b:
# 19.0
# l2 Евклидова норма вектора b:
# 13.0

# %%
cos_phi = np.dot(a, b) / norm(a) / norm(b)
print(f'Косинус угла: {cos_phi}')
# Out:
# Косинус угла: 0.8974358974358974

# %% [markdown]
# __3.__ Определите, будет ли линейное пространство евклидовым, если за скалярное произведение принять:<br>
# а) произведение длин векторов;<br>
# б) утроенное обычное скалярное произведение векторов?<br>

# %% [markdown]
# a) Линейное пространство над полем вещественных чисел называется _евклидовым пространством_, если на нём введено правило, согласно которому каждой упорядоченной паре векторов $x$ и $y$ поставлено в соответствие вещественное число, называемое _скалярным произведением_ и обозначаемое символом $(x, y)$.
#
# Нам известно, что в стандартном понимании в трёхмерном пространстве скалярное произведение двух векторов определяется как произведение длин этих векторов на косинус угла между ними.
#
# Указанное правило должно подчиняться четырём аксиомам:<br>
# 1) $(x,y)=(y,x).$<br>
# 2) $(\lambda x, y)=\lambda(x, y).$<br>
# 3) $(x_{1}+x_{2},y)=(x_{1},y)+(x_{2},y).$<br>
# 4) $(x, x)\geq0$, причём $(x,x)=0\Leftrightarrow x=0.$
#
# Ответ: данное линейное пространство является евклидовым.

# %% [markdown]
# b) Я предполагаю, что данное линейное пространство также является евклидовым, данные 4 аксиомы будут выполняться.

# %% [markdown]
# __4.__ Выясните, какие из нижеперечисленных векторов образуют ортонормированный базис в ортонормированный пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ <br>
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %% [markdown]
# a) $(1,0,0),(0,0,1);$ <br>
# не является ортонормированным, так как пространноство $\mathbb{R}^{3}$

# %% [markdown]
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>

# %%
x = np.array([1 / np.sqrt(2), -1 / np.sqrt(2), 0])
y = np.array([1 / np.sqrt(2), 1 / np.sqrt(2), 0])
z = np.array([0, 0, 1])

print(f'Скалярное произведение x, y и z:\n{np.dot(x, np.dot(y, z))}')
# Out:
# Скалярное произведение x, y и z:
# [0. 0. 0.]

# %%
x = np.array([1 / np.sqrt(2), -1 / np.sqrt(2), 0])
y = np.array([1 / np.sqrt(2), 1 / np.sqrt(2), 0])
z = np.array([0, 0, 1])

print(f'Скалярное произведение x на само себя:\n{np.dot(x, x)}')
print(f'Скалярное произведение y на само себя:\n{np.dot(y, y)}')
print(f'Скалярное произведение z на само себя:\n{np.dot(z, z)}')
# Out:
# Скалярное произведение x на само себя:
# 0.9999999999999998
# Скалярное произведение y на само себя:
# 0.9999999999999998
# Скалярное произведение z на само себя:
# 1

# %% [markdown]
# является ортонормированным

# %% [markdown]
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>

# %%
x1 = np.array([1/2, -1/2, 0])
y1 = np.array([0, 1/2, 1/2])
z1 = np.array([0, 0, 1])

print(f'Скалярное произведение x1, y1 и z1:\n{np.dot(x1, np.dot(y1, z1))}')
# Out:
# Скалярное произведение x1, y1 и z1:
# [ 0.25 -0.25  0.  ]

# %%
print(f'Скалярное произведение x1 на само себя:\n{np.dot(x1, x1)}')
print(f'Скалярное произведение y1 на само себя:\n{np.dot(y1, y1)}')
print(f'Скалярное произведение z1 на само себя:\n{np.dot(z1, z1)}')
# Out:
# Скалярное произведение x1 на само себя:
# 0.5
# Скалярное произведение y1 на само себя:
# 0.5
# Скалярное произведение z1 на само себя:
# 1

# %% [markdown]
# Не является ортонормированным

# %% [markdown]
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %%
x2 = np.array([1, 0, 0])
y2 = np.array([0, 1, 0])
z2 = np.array([0, 0, 1])
print(f'Скалярное произведение x2, y2 и z2:\n{np.dot(x2, np.dot(y2, z2))}')
# Out:
# Скалярное произведение x2, y2 и z2:
# [0 0 0]

# %%
print(f'Скалярное произведение x2 на само себя:\n{np.dot(x2, x2)}')
print(f'Скалярное произведение y2 на само себя:\n{np.dot(y2, y2)}')
print(f'Скалярное произведение z2 на само себя:\n{np.dot(z2, z2)}')
# Out:
# Скалярное произведение x2 на само себя:
# 1
# Скалярное произведение y2 на само себя:
# 1
# Скалярное произведение z2 на само себя:
# 1

# %% [markdown]
# является ортонормированным
